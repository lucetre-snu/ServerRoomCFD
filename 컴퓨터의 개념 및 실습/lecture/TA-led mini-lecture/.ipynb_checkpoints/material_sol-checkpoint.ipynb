# %% [markdown]
# ## Jupyter project using various Python APIs
# #### *ft. Twitter, Google NLP, Wordcloud*
# * **수업 목표: 다양한 API를 경험하여 원하는 기능을 프로젝트와 결합할 수 있는 실력을 갖춘다.**
#   1. Tweepy를 이용해 입력된 키워드 기준으로 트위터 내용을 크롤링할 수 있다.
#   2. Google Natural Language API를 이용해 문장을 입력했을 때 긍정적/부정적인지 감정분석을 할 수 있다.
#   3. Wordcloud 모듈을 이용해 입력된 문자열을 쪼개고 빈도수에 비례한 크기로 시각화할 수 있다.
# * ***What is API?***
#   * *Application Programming Interface, 응용 프로그램 프로그래밍 인터페이스는 응용 프로그램에서 사용할 수 있도록,<br> 운영 체제나 프로그래밍 언어가 제공하는 기능을 제어할 수 있게 만든 인터페이스를 뜻한다.*
#   * ex) Matrix multiplication using `numpy` API

# %%
A = [[1, 2, 3], [4, 5, 6]]
B = [[2, 4], [8, 10], [14, 16]]

# %%
if len(A[0]) != len(B):
    raise Exception()
[[sum(a*b for a, b in zip(rowA, colB)) for colB in zip(*B)] for rowA in A]
# Out:
# [[60, 72], [132, 162]]

# %%
import numpy as np
np.matmul(A, B)
# Out:
# array([[ 60,  72],
#        [132, 162]])

# %% [markdown]
# * ***Why using APIs?***
#   * API를 사용하면 우리가 제어 하고자 하는 시스템의 환경을 정확히 알지 못하더라도 손 쉽게 제어가 가능하다.
#   * UI가 사용자와 시스템의 인터페이스 였다면 API는 시스템과 시스템간의 인터페이스라고 할 수 있다.
#
# ![](https://swisscognitive.ch/wp/wp-content/uploads/2020/11/what-is-artificial-intelligence.png)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('QTgRNer2epE', width=800, height=450)

# %% [markdown]
# ### Twitter API
# * Get Access Token
#   1. [apps.twitter.com](https://apps.twitter.com)
#   2. Create an App > Fill an application
#   > *Hello? I'm Sangjun, Son, a student from Seoul National University. While doing TA works, I thought it would be great opportunities for students to experience various python features. I'll teach positive/negative sentiment analysis using keywords from twitter data (tweepy).*
#   3. Projects & Apps > Generate Access token & secret
#     * *API key, API secret key, Access token, Access token secret*

# %%
# !pip install tweepy

# %%
import tweepy

consumer_key = "VKlVlLNdrq7AGjUOvckzY9YMw"
consumer_secret = "o4daqr9r8qxv4eHlwKzvKnw0HGpz7qVX8aaPqkOfdu56w87L3i"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

access_token = "1333657224887951362-N1i7ZX9Kh8PwuIvVN7P4jshcYwTLla"
access_token_secret = "WX1mDwtpbt8gsN1coJsqPXWVVz06y0tHkRCHl7SVV2D2M"
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
keyword = "민트초코"
cursor = tweepy.Cursor(api.search, q=keyword, since='2020-01-01', count=100, include_entities=True)
for i, tweet in enumerate(cursor.items()):
    print("{}: {}".format(i, tweet.text))
# Out:
# 0: (ㅋㅋ) 그럴실 줄 알았습니다................... 홍차에 민트초코 타 드려야지... https://t.co/wUJMLtnaxD
# 1: 코 끝에선 화➰❤ 입안에선 후➰💚 때론 달콤하게🍫 때론 시큰하게🌿 민트초코가 세상을 지배한다🍦코 끝에선 화➰❤ 입안에선 후➰💚 때론 달콤하게🍫 때론 시큰하게🌿민트초코가 세상을 지배한다🍦코 끝에선 화➰❤ 입안… https://t.co/OOMLWgTOWl
# 2: 민트초코가 왕실의 음식이라던데, 저는 취향이 아니더라고요. 아직 고귀해지기 위한 수련이 부족한 걸까요?
# 3: 지금
# 마황님
# 룽이언니
# 민트초코 있습니다
# 4: 4. 민트 초코를 먹을 줄 아는 여우.
# 5: @HJ__13_ 라떼는말이야..
#
# 민트초코라떼♥
# 6: RT @topstarnews: “입맛 왜 이래”…임시완, 민트 초코 이어 하와이안 피자? 음식 취향 공개 #임시완 #임시완민트초코 #임시완하와이안피자 #임시완입맛 #임시완음식취향 https://t.co/ptpynmUFDD
# 7: 저는민초파이고슈붕파입니다반박은민트초코레귤러로받습니다
# 8: 요즘 카누 민트초코라떼에 빠졌다...민트맛은 많이 안남ㅎㅎ
# 9: RT @moonjunhyeok501: 베스킨라벤스 31에 제안합니다.
#
# 며칠 뒤면 대통령 박근혜 탄핵소추안이 통과된지 4주년이 되는 날입니다.  이날은 민초(民草)데이로 지정해주시고 민트초코 40% 세일 해주시면 감사하겠습니다.
# 10: RT @no_doubtist: 민트초코 OUT https://t.co/0T4RyCzeqe
# 11: RT @hylovestea: 그동안 먹어본 민초차 이야기
#
# 마리아쥬 초코민트 : 존..맛없..
#
# 베티나르디 민티초콜릿 : 이게 홍차인가 싶을 정도로 홍차 비중이 적고 맛도 그런데 묘하게 매력적임 진짜 초콜릿이 들어서 밀크티 하면 맛있다
#
# 스미스티 초…
# 12: 민트초코 OUT https://t.co/0T4RyCzeqe
# 13: 민트초코는 보이는 즉시 도주할 정도로 싫어하지만
#
# 이상하리만치 파인애플 피자는 너무 자주 먹는 수준만 아니라면 생각보다 맛있더라
#
# 파인애플 조아~ https://t.co/m3YS0o3zEA
# 14: 캔모아 - 이름은 들었는데 같은나이대 친구들은 알고있음 난 먹은 기억도 간 기억도 없음
# 민토 - 민트초코 오타인줄 알았음...
# 쏘렌토 - 자동차 이름 아닌가요...
# 15: 탐라의 민초단분들 이거 드세욧 그 머지 초코찰떡인가 그 찰떡파이재질인데 안에 민트 엄청 화해서 진짜 최고예요ㅠㅠ https://t.co/10COHV1j0e
# 16: RT @muraegi: 거래틧 죄송합니다 웰컴 깅엄 찾습니다..
# 하늘색&gt;&gt;&gt;&gt;&gt;연보라색, 민트색 순으로 구하고 있고 (빨강은 구하지 않습니다) 하늘색과 연보라색은 세트로만 받습니다!
# 하늘색이랑 스위트피는 0.5~0.7 사이에서, 초코민트는 0.5 이…
# 17: @DD_EOA 호박죽은 좋아하는구나... 난 호박죽도 못 먹겠더라. 드와이트는 민트초코 좋아해? 호불호 많이 갈리는 거!
# 18: @dimdimdawn 민트초코와 먹어본 적 없지만 베리베리 스트로베리..ㅋㅋㅋ
# 19: RT @hslove126: 너무 당연하다는듯이 '민트초코' 했는데 토피넛라떼 나와서 '아~토피넛..' 하고 쓰읍..하 하면서 의미심장한 씁쓸한 미소를 짓는 연상.. 아무래도 연하에 대한 문제를 틀린게 좀 자존심 상한걸까
# #훈선 https://t.co…
# 20: @SONI__M ㅋㅋㅋㅋㅋㅋ 저 아이스크림 귀신인데 댓 보니까 민트초코 땡기네욥!!
# 21: 영재는 파스타 만들고, 재범이는 민트초코사람들 열심히 대변하고, 뱀이는 방구석 콘서트하고.. 겸이 춤방하고, 이런거 할 수 있잖아? @GOT7Official https://t.co/dHvGKQRBWC
# 22: 유행하는 민트초코라떼 먹어봤는데 단맛이 부족하구만
# 23: [월드컵]
# 싫어하는 음식 고르기
# https://t.co/RUZbewpd6t
# ────────────────────
# ♛ 최종우승: 민트초코
# ♚ 준우승: 브로콜리
# ♝ 3위: 취두부
# ♞ 4위: 맥콜
# 24: RT @muraegi: 거래틧 죄송합니다 웰컴 깅엄 찾습니다..
# 하늘색&gt;&gt;&gt;&gt;&gt;연보라색, 민트색 순으로 구하고 있고 (빨강은 구하지 않습니다) 하늘색과 연보라색은 세트로만 받습니다!
# 하늘색이랑 스위트피는 0.5~0.7 사이에서, 초코민트는 0.5 이…
# 25: RT @muraegi: 거래틧 죄송합니다 웰컴 깅엄 찾습니다..
# 하늘색&gt;&gt;&gt;&gt;&gt;연보라색, 민트색 순으로 구하고 있고 (빨강은 구하지 않습니다) 하늘색과 연보라색은 세트로만 받습니다!
# 하늘색이랑 스위트피는 0.5~0.7 사이에서, 초코민트는 0.5 이…
# 26: RT @muraegi: 거래틧 죄송합니다 웰컴 깅엄 찾습니다..
# 하늘색&gt;&gt;&gt;&gt;&gt;연보라색, 민트색 순으로 구하고 있고 (빨강은 구하지 않습니다) 하늘색과 연보라색은 세트로만 받습니다!
# 하늘색이랑 스위트피는 0.5~0.7 사이에서, 초코민트는 0.5 이…
# 27: RT @muraegi: 거래틧 죄송합니다 웰컴 깅엄 찾습니다..
# 하늘색&gt;&gt;&gt;&gt;&gt;연보라색, 민트색 순으로 구하고 있고 (빨강은 구하지 않습니다) 하늘색과 연보라색은 세트로만 받습니다!
# 하늘색이랑 스위트피는 0.5~0.7 사이에서, 초코민트는 0.5 이…
# 28: @bbu_ma_0613 민트초코의 상큼함과 달콤함은 혁명입니닫
# 29: 거래틧 죄송합니다 웰컴 깅엄 찾습니다..
# 하늘색&gt;&gt;&gt;&gt;&gt;연보라색, 민트색 순으로 구하고 있고 (빨강은 구하지 않습니다) 하늘색과 연보라색은 세트로만 받습니다!
# 하늘색이랑 스위트피는 0.5~0.7 사이에서,… https://t.co/BhhB2qhG5O
# 30: @Kim_Lamin 오레오 초코민트
# 31: RT @moonjunhyeok501: 베스킨라벤스 31에 제안합니다.
#
# 며칠 뒤면 대통령 박근혜 탄핵소추안이 통과된지 4주년이 되는 날입니다.  이날은 민초(民草)데이로 지정해주시고 민트초코 40% 세일 해주시면 감사하겠습니다.
# 32: 거북이 민트초코케이크 속은 초코맛이려나?
# 33: 나 갑자기 민트초코가 무슨맛이었는지 기억이 안난다
# 84: RT @May_be_jb: 잘생긴얼굴로 갱장히 진지하게 민트초코사람들을 대표해서 반민초파를 향해 취향존중해 주시기를 진정성을 담아 완곡하게 말하고 계신 우리 민초대장님ㅠㅠ 근데 진지하신 와중에 죄송하지만 까맣고 짧뚱한 손톱이 너무 귀여워요...ㅠㅠㅠ…
# 85: 민트초코는 죄없어 생각하면서 벌써 열 개 먹었어
# 86: 존나피곤하니까 민트 초코 먹을거림
# 87: @SSSS_N4K3_ 정육점 고기를 죄다 쓸어담은 주제에 할 말은 아니라고 생각하는데. (카트 한 쪽에 민트 초코를 잔뜩 담아두고 다른 쪽으로 카트를 밀며) 대충 다 산 거 같고, 이제 라면만 두 봉지 사면 되겠네.
# 88: @0613Vv 민트초코랑 초쿼ㄹ릿
# 89: @milkmelonasoda 아 당근빳다 민트초코죠
# 90: @E__Y0N_ ( 조각을가졌다는 말에 입을 다물곤 민트초코 잔뜩 담는 네옆에서 쳐다보기만 하다가) 작작 담지. 못먹다 죽은것처럼 보이지마 없어보여 너.
# 91: 요즘 중독된 것
# 덴마크 민트초코,카페라테민트
# 원래 좋아했지만 요즘 지나치게 맛있는 듯
# 92: @hinapong7 초면이지만..민트초코 도넛은..어떤 맛이죠..?
# 93: 오이 : 민트초코랑 하와이안 피자를 먹는 놈들은 사람이 아니야!!!!!!!
# 당솔 : 어? 나 두개 다 먹는데 사람 아니야?
# 오이 : 사실 사람이 아니라 천사였던거야.
#
# (출처 카피페 모음봇) https://t.co/aOIBVr3IQ7
# 94: RT @iamyangdog: 시나모롤 인형 정리차 양도합니다
#
# 일괄시 택포 17
# 보석눈은 다른 인형 같이 구매시 가능합니다
#
# 힐링인형 초코민트 니트모자 카라비너 퓨로랜드 교복 해변 바캉스 우치와 경찰 보석눈 산리오
#
# Gs반택 1600 편택 3000…
# 95: RT @iamyangdog: 시나모롤 인형 정리차 양도합니다
#
# 일괄시 택포 17
# 보석눈은 다른 인형 같이 구매시 가능합니다
#
# 힐링인형 초코민트 니트모자 카라비너 퓨로랜드 교복 해변 바캉스 우치와 경찰 보석눈 산리오
#
# Gs반택 1600 편택 3000…
# 96: RT @ianifest: 🎵[32인곡] 32명의 멘티가 만들어낸 32가지 이야기🎵
# 🎥웹애니메이션으로 꽉 채운 월요극장
# 🔸지글지글 용암에서 온천을? &lt;별의 별&gt; EP2
# 🔸민트초코는 시작에 불과했다. 호불호의 끝판왕! &lt;교승인 단편선&gt; EP1
# 🔸신입사원…
# 97: @TEEN_TOP #틴탑_N행시
#
# 방 : 방금 영상을 하나 봤어요!
# 민 : 민트초코 먹으면서요
# 수 : 수퍼럽 재탕 해야겠네 💜
#
# 틴 : 틴타비들 많이 사랑해주세요!
# 탑 : 탑 of 탑이 뭔지 보여드립니다😏
# 98: RT @May_be_jb: 잘생긴얼굴로 갱장히 진지하게 민트초코사람들을 대표해서 반민초파를 향해 취향존중해 주시기를 진정성을 담아 완곡하게 말하고 계신 우리 민초대장님ㅠㅠ 근데 진지하신 와중에 죄송하지만 까맣고 짧뚱한 손톱이 너무 귀여워요...ㅠㅠㅠ…
# 99: RT @ianifest: 🎵[32인곡] 32명의 멘티가 만들어낸 32가지 이야기🎵
# 🎥웹애니메이션으로 꽉 채운 월요극장
# 🔸지글지글 용암에서 온천을? &lt;별의 별&gt; EP2
# 🔸민트초코는 시작에 불과했다. 호불호의 끝판왕! &lt;교승인 단편선&gt; EP1
# 🔸신입사원…
# 100: @XPHecoX 민트초코와 가까이 할 수 있는 삶은 부럽구마
# 101: 풀타입이 제일 많았던 것 같은데 풀조지기 2위러 어리둥절되엇고 현질보태서 물라우들엿다...(가자우리민트초코.....) https://t.co/wLHYE8A6a6
# 102: 🎵[32인곡] 32명의 멘티가 만들어낸 32가지 이야기🎵
# 🎥웹애니메이션으로 꽉 채운 월요극장
# 🔸지글지글 용암에서 온천을? &lt;별의 별&gt; EP2
# 🔸민트초코는 시작에 불과했다. 호불호의 끝판왕! &lt;교승인 단편선&gt;… https://t.co/9HdcHKWKkU
# 103: 민트랑 초코 둘다 그다지 좋아하지않는
# 졸모씨의 일그러지는표정
# (편가르고 뭐하세요 둘다 내 적이야) https://t.co/JbpbDxs5Kl
# 104: 붕어빵은 다 옳다파(김치붕어빵도 먹었음)
# 아이스크림을 잘 안먹지만 민트초코는 먹음
# 복숭아는 다 옳다파
# 105: RT @S4NB_: #쿠키런 #cookierun
# 💚민트초코 + 민초스킨
#
# 바래다줄게. 바래? 다 줄게. https://t.co/vUJjW74cvf
# 106: 오늘은.. 민트초코 해먹어야즤~
# 107: 여기 맛집이에요 다들 둘러보세요 진짜.. 개쩔거든요? 성우분들 연기도.... 쩜
# 몸 쓰는 능글백발캐
# 머리 쓰는 능글금발캐
# 아마도 자낮다정흑발캐
# 해커츤데레 민트초코캐
# 귀여움과 열정이 가득 적발캐
#
# 다들 맛보세… https://t.co/pySI4UolQG
# 108: 민트 초코는 호불호 어쩌구 나올때마다 거의 1순위로 나오는 질문의 항목 아닌가? 사실상 국민의 절반이 좋아한다는 말이라(아님)
# 109: ..나 입시할 때 항상 컵라면에 마지막에 민트초코 우유를 마셨는데, 이게 이상한건지 몰랐음
# 그냥 난..초코를 좋아하고 라면도 좋아해서..라면 다 먹고 초코우유를 마신건데..그 둘의 조화가 남이 들으면 이상할거라는 생각을 못함 ㅋㅋㅋㅋ
# 110: RT @ZeBread_art: https://t.co/5sLwqo6SSh
#
# 네이버 도전만화에 새 작품 '민트초코 캔디' 1화를 업로드하였습니다. 들어오셔서 한번 봐주시면 정말 감사하겠습니다 ㅠ.ㅠ 힝힝
# 111: @MILKY__WAY__28 ㅋ
# ㄲ
# ㄱ
# ㅋ
# ㄱ하......너무귀엽다....벌써귀엽다......저 설레요 오늘부터 민트초코만 먹겠습니다 배라문열고기다려라
# 112: RT @Ga_Ya_: 밀회의 그 대사... 사실 용감한 쿠키가 민트초코 쿠키의 성격 사나운 부분을 이미 알고 있었다는 전개가 좋다 https://t.co/yOHj2FbnGl
# 113: @quinn_168 @olgamijinsim 근데 사람들말로는 치약이 민트초코맛이래요
# 우아해날해치는크리미널
# 229: 암잔나 색감이 민트초코인게 너무너무너무 좋다 눈색은 민트초코 위에 포인트로 뿌려진 그 스프링클? 그거같아 너무산뜻하고 귀여워 https://t.co/oqhpZ9b3zA
# 230: RT @ZWEDqOvSQ86Zs7C: 아까아무말어떻게했었지
# #태민_퍼포먼스메일솔로상_축하해
# 카누의깊은맛과민트초코의달콤함을어쩌규
# #인간계에서_상받은_메시아태민
# 우아해날해치는크리미널
# 231: 아쌈! 푸딩! 마카롱! 슈크림! 민트초코! 주거라 달란말이다! (파닥거리며, 땡깡부리고있다.) #Bot
# 232: RT @ZWEDqOvSQ86Zs7C: 아까아무말어떻게했었지
# #태민_퍼포먼스메일솔로상_축하해
# 카누의깊은맛과민트초코의달콤함을어쩌규
# #인간계에서_상받은_메시아태민
# 우아해날해치는크리미널
# 233: RT @ZWEDqOvSQ86Zs7C: 아까아무말어떻게했었지
# #태민_퍼포먼스메일솔로상_축하해
# 카누의깊은맛과민트초코의달콤함을어쩌규
# #인간계에서_상받은_메시아태민
# 우아해날해치는크리미널
# 234: RT @ZWEDqOvSQ86Zs7C: 아까아무말어떻게했었지
# #태민_퍼포먼스메일솔로상_축하해
# 카누의깊은맛과민트초코의달콤함을어쩌규
# #인간계에서_상받은_메시아태민
# 우아해날해치는크리미널
# 235: RT @ZWEDqOvSQ86Zs7C: 아까아무말어떻게했었지
# #태민_퍼포먼스메일솔로상_축하해
# 카누의깊은맛과민트초코의달콤함을어쩌규
# #인간계에서_상받은_메시아태민
# 우아해날해치는크리미널
# 236: RT @ZWEDqOvSQ86Zs7C: 아까아무말어떻게했었지
# #태민_퍼포먼스메일솔로상_축하해
# 카누의깊은맛과민트초코의달콤함을어쩌규
# #인간계에서_상받은_메시아태민
# 우아해날해치는크리미널
# 237: 아까아무말어떻게했었지
# #태민_퍼포먼스메일솔로상_축하해
# 카누의깊은맛과민트초코의달콤함을어쩌규
# #인간계에서_상받은_메시아태민
# 우아해날해치는크리미널
# 238: 허얼 콤비조합 기엽다 민트초코코코아냐구요.... 민초라떼...먹고싶다.. ... ...
# 239: @GL0R10US_ 므아앍-!! 아워어엉-!! 먉-!!아우우우우-💕
# (너무너무 시원해-!! 민트초코 요정님 정말 최고야-! 그론달을 이렇게 시원하게 긁어준 사람은 처음이야!!)
# (녹아버린 멈머-!)
# 240: RT @ong2_song2: 하루 늦은 형아 수상 축하 소감(?)
#
# 민트초코람지 그거 너무나 옹쀼 아닌가요?
#
# 이제서야 첫사진 찍어준 옹쀼ㅜㅜ
# 너무 ㄱㅇㅇ💕 https://t.co/Xj6NdbjlcH
# 241: RT @ong2_song2: 하루 늦은 형아 수상 축하 소감(?)
#
# 민트초코람지 그거 너무나 옹쀼 아닌가요?
#
# 이제서야 첫사진 찍어준 옹쀼ㅜㅜ
# 너무 ㄱㅇㅇ💕 https://t.co/Xj6NdbjlcH
# 242: RT @2jae131page: 🌴🌙
# 뽐재전력 26회 주제
#
# - 민트초코
# - 차 안에서
# - 나와 함께 사랑해볼래
# 256: (내가 그럴 시간이나 있어 보여? 그리고 내가 보기엔 치약이나 민트 초코나 다를 것 없는데 무어가 그리 문제가 되는 건지 도저히 이해하기 어렵군. 차라리 치약을 사먹으라고.)
# 257: 민트초코가 왕실의 음식이라던데, 저는 취향이 아니더라고요. 아직 고귀해지기 위한 수련이 부족한 걸까요?
# 258: 뭐라고? 이건 민트초코계의 붕괴야! https://t.co/nqcqtRHcq6 https://t.co/DyLchWbgJJ
# 259: 영원호현은 영원이는 초코만 좋아하고 호현이는 민트만 좋아해서 결과적으로 둘 다 민초 안 좋아한단 게 ㄹㅇ 갓컾이야(?)
# 260: (너………… … 지금 민트초코 대신 치약을 건네준다는 말 진심이야? 실화? 그건 민트초코계의 붕괴라고!!!!! 아침에 일찍 일어나서 삼거리 제과점에서 인기 메뉴인 민트초코 상품이라도 사오는 정성을 보여!!!!)
# 261: 🌴🌙
# 뽐재전력 26회 주제
#
# - 민트초코
# - 차 안에서
# - 나와 함께 사랑해볼래
# 주제의 선택 개수 및 해석, 연성형식은 자유입니다.
#
# 토요일 오후 1시 6분에 만나요!
# 262: @ED_EN_304 민트 초코 말고 다른 걸로 식사 챙기는 날이라... 일주일에 세 네번? 한 번 노력을 해볼게. 도장 받아야지.
# 263: (내가 지금 민트 초코를 지니고 있을 리 없잖아. ……아, 치약을 대신해서 줘보는 것은 어떠하지?)
# 264: (야~ 저걸 내가 어떻게 말려! 네가 먼저 잘 못 했잖아. 임마! 슈나이더가 바라는 그대로 민트초코라도 같이 먹어주라구.) (프라우식 윙크!)
# 265: RT @hslove126: 너무 당연하다는듯이 '민트초코' 했는데 토피넛라떼 나와서 '아~토피넛..' 하고 쓰읍..하 하면서 의미심장한 씁쓸한 미소를 짓는 연상.. 아무래도 연하에 대한 문제를 틀린게 좀 자존심 상한걸까
# #훈선 https://t.co…
# 266: 4. 민트초코
# 267: RT @got7_bonito: 우리 재버미는 민초에 진심이라 민초단이라는 단어도 안쓰고...민트초코사람들이라고 한다구여!ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# https://t.co/5GNf5n4oiR
#
# 여기서 다른 사람들 댓글이랑 같이보니까 더 재밌넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ…
# 268: @9t4i12d_F0X 붉은 여우 모양 도장이라. 좋아요. 그런데 민트 초코로 식사 안 챙기는 날이 있긴 한 거죠? 하루에 한 끼는 제대로 된 식사로 챙겨요.
# 269: 초코맛 새알심... 옅은 쑥맛 새알심..
# (민트색이긴한데 그렇다고 민트맛새알심이라고 할 순 없잖아요)
# 270: 민트초코
# 271: RT @TODAK_JB: 민트초코사람은 ㅋㅋㅋㅋㅋㅋ 강요하지 않아 ㅋㅋㅋㅋㅋㅋㅋㅋ 민트초코사람 ㅋㅋㅋㅋㅋㅋㅋㅋ열변중이야 https://t.co/4qr00FfdQJ
# 272: @99tailse9 (네가 느닷없이 웃는 탓에 괜히 제 귀가 다 붉어지는 것 같은 기분이다. 잔뜩 화끈거리는 얼굴을 숨기려 고개를 숙이고 호두를 몇 개 더 집어 입에 넣고) ·····.  형이랑 아이스크림… https://t.co/NO92JoJQOj
# 273: RT @got7_bonito: 우리 재버미는 민초에 진심이라 민초단이라는 단어도 안쓰고...민트초코사람들이라고 한다구여!ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# https://t.co/5GNf5n4oiR
#
# 여기서 다른 사람들 댓글이랑 같이보니까 더 재밌넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ…
# 394: RT @got7_bonito: 우리 재버미는 민초에 진심이라 민초단이라는 단어도 안쓰고...민트초코사람들이라고 한다구여!ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# https://t.co/5GNf5n4oiR
#
# 여기서 다른 사람들 댓글이랑 같이보니까 더 재밌넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ…
# 395: RT @nadooarang: 하 오늘 임재범 민트초코 연설 진짜 감동먹었다 30만 명에게 전파해줘서 너무 고맙다 이 시대의 진정한 지성인 임. 재. 범. 민초단 만세!!!!!!!
# 396: RT @Nayeon_1015_: 민트초코먹고싶다아이게아니지
# #소정이의_소원이_다_이루어지길
# 밤밤밤밤에밤하늘을날아
# #BestLeaderSowonDay
# 에스타임타임폴더문나잇
# 397: RT @got7_bonito: 우리 재버미는 민초에 진심이라 민초단이라는 단어도 안쓰고...민트초코사람들이라고 한다구여!ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# https://t.co/5GNf5n4oiR
#
# 여기서 다른 사람들 댓글이랑 같이보니까 더 재밌넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ…
# 398: RT @got7_bonito: 우리 재버미는 민초에 진심이라 민초단이라는 단어도 안쓰고...민트초코사람들이라고 한다구여!ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# https://t.co/5GNf5n4oiR
#
# 여기서 다른 사람들 댓글이랑 같이보니까 더 재밌넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ…
# 399: RT @got7_bonito: 우리 재버미는 민초에 진심이라 민초단이라는 단어도 안쓰고...민트초코사람들이라고 한다구여!ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# https://t.co/5GNf5n4oiR
#
# 여기서 다른 사람들 댓글이랑 같이보니까 더 재밌넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-507f672bb90e> in <module>
#       1 keyword = "민트초코"
#       2 cursor = tweepy.Cursor(api.search, q=keyword, since='2020-01-01', count=100, include_entities=True)
# ----> 3 for i, tweet in enumerate(cursor.items()):
#       4     print("{}: {}".format(i, tweet.text))
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     217         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     218             # Reached end of current page, get the next page...
# --> 219             self.current_page = self.page_iterator.next()
#     220             while len(self.current_page) == 0:
#     221                 self.current_page = self.page_iterator.next()
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     128
#     129         if self.index >= len(self.results) - 1:
# --> 130             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     131
#     132             if hasattr(self.method, '__self__'):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     683
#     684         if not stream:
# --> 685             r.content
#     686
#     687         return r
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     573         else:
#     574             while not is_fp_closed(self._fp):
# --> 575                 data = self.read(amt=amt, decode_content=decode_content)
#     576
#     577                 if data:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     516             else:
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#     520                     amt != 0 and not data
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     499         # connection, and the user is reading more bytes than will be provided
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#     503             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Google Natural Language API
# * [Documentation](https://cloud.google.com/natural-language/docs/quickstarts)
# * [console.cloud.google.com](https://console.cloud.google.com)
#   * API Library > Cloud Natural Language API > 사용
#   * 사용자 인증 정보 만들기 > [API 키](https://console.cloud.google.com/apis/credentials/serviceaccountkey?_ga=2.149612351.88419587.1606806283-1529152370.1593052341) (json)
# * Google Cloud Installation
#   * `pip install --upgrade google-cloud-language`

# %%
# !pip install --upgrade google-cloud-language

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="./dccp.json"

# %%
# Imports the Google Cloud client library
from google.cloud import language_v1

# Instantiates a client
client = language_v1.LanguageServiceClient()

# The text to analyze
text = "컴개실 실습은 행복 그 자체다. 매일 설렌다. 재밌다. 즐겁다."
document = language_v1.Document(content=text, type_=language_v1.Document.Type.PLAIN_TEXT)

# Detects the sentiment of the text
sentiment = client.analyze_sentiment(request={'document': document}).document_sentiment

print("Text: {}".format(text))
print(sentiment)
# Out:
# Text: 컴개실 실습은 행복 그 자체다. 매일 설렌다. 재밌다. 즐겁다.
# magnitude: 1.5
# score: 0.30000001192092896

# %% [markdown]
# ### Word Cloud
# * `pip install wordcloud`
# * Add font style *font.ttf* in the same directory

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = '과거 토트넘에서 활약했던 공격수 저메인 데포(38)가 손흥민(28)과 해리 케인(27)의 호흡에 박수를 보냈다. 데포는 1일(한국시간) 영국 매체 데일리 메일과의 인터뷰에서 "토트넘의 손흥민과 케인 콤비는 현재 세계 최고의 파트너십을 보여주고 있다"며 높게 평가했다. 올 시즌 손흥민과 케인은 잉글랜드 프리미어리그(EPL)에서 총 9골을 합작하고 있다. 손흥민은 케인의 도움을 받아 7골을 넣었고, 케인의 2골을 어시스트했다.'
wordcloud = WordCloud(font_path='./font.ttf', background_color='white', width = 800, height = 800).generate(text)

plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='lanczos')
plt.axis('off')
plt.show()

# %% [markdown]
# ### *Putting them together*

# %%
import tweepy
import os, sys
import matplotlib.pyplot as plt
from google.cloud import language_v1
from wordcloud import WordCloud, STOPWORDS

def initialize_tweepy(keyword):
    consumer_key = "VKlVlLNdrq7AGjUOvckzY9YMw"
    consumer_secret = "o4daqr9r8qxv4eHlwKzvKnw0HGpz7qVX8aaPqkOfdu56w87L3i"
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

    access_token = "1333657224887951362-N1i7ZX9Kh8PwuIvVN7P4jshcYwTLla"
    access_token_secret = "WX1mDwtpbt8gsN1coJsqPXWVVz06y0tHkRCHl7SVV2D2M"
    auth.set_access_token(access_token, access_token_secret)

    api = tweepy.API(auth)
    
    return tweepy.Cursor(api.search, q=keyword, since='2020-01-01', count=100, include_entities=True, lang='ko')
    
def initialize_google():
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="./dccp.json"
    return language_v1.LanguageServiceClient()

def get_sentiment(client, text):
    document = language_v1.Document(content=text, type_=language_v1.Document.Type.PLAIN_TEXT)
    sentiment = client.analyze_sentiment(request={'document': document}).document_sentiment
    return sentiment

def show_wordcloud(good_text, bad_text):
    stop_words = ["https", "co", "RT", 't'] + list(STOPWORDS)
    wordcloud = WordCloud(font_path='./font.ttf', stopwords=stop_words, background_color='white', width = 800, height = 800).generate(good_text)
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud, interpolation='lanczos')
    plt.axis('off')
    plt.show()
    
    wordcloud = WordCloud(font_path='./font.ttf', stopwords=stop_words, background_color='black', width = 800, height = 800).generate(bad_text)
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud, interpolation='lanczos')
    plt.axis('off')
    plt.show()

# %%
good_text = ''
bad_text = ''

cursor = initialize_tweepy(input())
client = initialize_google()

for i, tweet in enumerate(cursor.items()):
    if i > 100: break
    text = tweet.text
    sentiment = get_sentiment(client, text)
    print(f"{i}: {text} {sentiment.score}")

    if sentiment.score > 0.2:
        good_text += text
    elif sentiment.score < -0.2:
        bad_text += text
# Out:
#  수능
# 0: RT @mu__VIEW: 난 얘보면 하나밖에 생각안남... 2011년도 수능 직후에 자기 출신 여자고등학교 가서 고2~3학생들 모아 놓고 여성을 위한 정책이 부족하니 여성 대통령이 필요하다더니 그 예시로 여자들 하이힐 많이 신는데 보도블럭이 너무 위… -0.10000000149011612
# 1: RT @mafavarchive: 💖 수능 이벤트 안내 💖
#
# 참여기간: 12월 7일 - 12월 12일
#
# 총 10분 추첨, 당첨 되신 분들에게 스티커팩을 보내드립니다! 모두 정말 수고 많으셨어요 💖
#
# https://t.co/72T2PoxOAT http… 0.4000000059604645
# 2: [2020년 12월 1주차] 타파크로스 주간이슈
# 주간이슈 TOP10 입니다.
# 아래 내용은 타파크로스 홈페이지(https://t.co/hVDv8tKH48)에서도
# 확인하실 수 있습니다.
#
# #타파크로스… https://t.co/kqQTKRKnTe 0.0
# 3: RT @615X77: 성인 되자마자 서로에게 처음이 되자고 약속한 동갑내기 룡율. 그런데 수능 끝나자 마자 아무런 소식도 남기지 않고 사라져 버린 김성룡이었음...
# 그러고 13년 후 32살 티큐 이사 서율과 호빠 장부 관리해주는 김성룡으로 재회하는… -0.10000000149011612
# 4: 아니씨팔
# 나 6월달부터 거래했는데
# 얘가 계속 안보내주는거임
# 고3이라길래 수능 끝날때까지
# 기다려줬는데 아직도 연락이없네
# 하... 대학붙기전에 빨간줄 그을거야? -0.5
# 5: RT @KBSnews: “수능 물리Ⅱ 18번 문항 오류…정답없음 처리 예상” #KBS뉴스 #KBS https://t.co/oW2ad3NjMj 0.0
# 6: #아라시_트친소
#
# 매 순간 최애가 바뀌는 아라시 올담입니다!! 수능 끝나서 계정 만들었는데 트위터 쓰는것도 처음이라 어어으어뭐가뭔지 모르겠지만 일단은 그림 끄적거리고 아라시 방송보고 노래듣고 네 그럼니다..… https://t.co/vMyhKJ5API 0.30000001192092896
# 7: RT @B_hundred_Hyun: 수능 보는 에리들은 얼른자! 0.20000000298023224
# 8: 아이패드 에어 10.9 4세대 8세대 애플워치 맥북 프로 에어팟 애플펜슬 https://t.co/29IWZ61LJ4 2020 블랙프라이데이 수능 크리스마스 선물 노트북  쿠팡 아이폰 12 미니 pro max… https://t.co/WGyJZA2RFX 0.10000000149011612
# 9: RT @09w_000: 수능 끝난 기념으로 트친소 합니다~~~
# #주술회전_트친소
# 저와 함께 고죠후시, 옷토게 파실 분?!! https://t.co/2hqNv5dyDV 0.20000000298023224
# 10: RT @pledis_17: [17'S 승관] 부끄가 수능 수고했대요!!🥰 https://t.co/Z0eudD7O8v 0.5
# 11: @rmqqkfwls 내신이랑 수능.... 정석방법은 아니었음 0.20000000298023224
# 12: RT @KINGKKANG_DINOS: 누구는
# 수험생혜택 빕스50%와 롯월63%를
# 참으며살아가는데
# 수능친날도배달음식먹고
# 내마지막외출은 수능인채로
# 집에서썩어가는데진짜
# 좀사리ㅡㅁ들이 xx
# 이제내마지막소원은 돼지국밥뿐인데
# 왜집에있질않아 내년에안전하게같이가자고 -0.10000000149011612
# 13: RT @mafavarchive: 💖 수능 이벤트 안내 💖
#
# 참여기간: 12월 7일 - 12월 12일
#
# 총 10분 추첨, 당첨 되신 분들에게 스티커팩을 보내드립니다! 모두 정말 수고 많으셨어요 💖
#
# https://t.co/72T2PoxOAT http… 0.4000000059604645
# 14: RT @crepie_Melo: #좀비고_트친소
# #현우빈_트친소
# #진호케빈_트친소
#
# 애스크로 트친소 열어달라는 질문이 들어와서 수능 끝난 기념으로 트친소 올려봐요!
# 현우빈,진케 등등 비엘 위주 그림연성러고 다른 연성들도 많이 합니당
# 알티 마음 맞는… 0.4000000059604645
# 15: RT @KINGKKANG_DINOS: 누구는
# 수험생혜택 빕스50%와 롯월63%를
# 참으며살아가는데
# 수능친날도배달음식먹고
# 내마지막외출은 수능인채로
# 집에서썩어가는데진짜
# 좀사리ㅡㅁ들이 xx
# 이제내마지막소원은 돼지국밥뿐인데
# 왜집에있질않아 내년에안전하게같이가자고 -0.10000000149011612
# 16: RT @KBSnews: “수능 물리Ⅱ 18번 문항 오류…정답없음 처리 예상” #KBS뉴스 #KBS https://t.co/oW2ad3NjMj 0.0
# 17: @xbxkiki 학교쌤들이 수능감독관으로 다른 학교 가셨는데...한 학교에서 감독관 선생님 중 한 분이 확진 되셔서...자가격리 해야한대요...
#
# ㅎㅎ귀찮아서 복붙 0.10000000149011612
# 18: 애플 맥북 에어 프로 13 사전예약 떴어요! https://t.co/MvrixUgnCK 여기도 금방 품절될듯...크리스마스 선물 수험생 수능 선물로 받고싶다ㅠ 맥북 에어 프로13인치2020 제휴커미션 받을수있음s66 0.5
# 19: RT @E_i_s_e: 데드맨 스위치 영원&amp;호현 수능썰 (고등학교 AU의 연장선으로 보아주세요😘) https://t.co/jFd0ih2Tub 0.0
# 20: RT @hatsucos111: #코스어_트친소
#
# 안녕하세요!
# 수능 때문에 계폭했다가 다시 돌아왔어요 😋
# 1년이나 덕질 쉬어서 버닝 장르.. 지금은 딱히 없지만 디즈니, 웹툰 위주로 파고있어요!
# 약네랜, 하이큐, 도쿄구울은 마음의 고향입니다 🥺💗
#
# 전… 0.4000000059604645
# 21: RT @E_i_s_e: 데드맨 스위치 영원&amp;호현 수능썰 (고등학교 AU의 연장선으로 보아주세요😘) https://t.co/jFd0ih2Tub 0.0
# 22: RT @pledis_17: [17'S 승관] 부끄가 수능 수고했대요!!🥰 https://t.co/Z0eudD7O8v 0.5
# 23: RT @norang_7_0613: #아미트친소
# 53: 와우 드디어 출시 아이폰 12 미니 pro max 사전예약 https://t.co/FNw8VIfAyU 2020 블랙프라이데이 크리스마스 수능 선물 노트북 쿠팡 아이폰12 프로 맥스 사전예약 iphone12… https://t.co/ACbWdMPZBg 0.4000000059604645
# 54: @17O623_ 괜찮아 사실 연락해보려 했는데 수능도 있고 .. 나도 바빠서 못했어 가끔 비계에 생각나서 언니 얘기 썼었는데 오랜만에 보니까 완전 반가워 🥺 0.30000001192092896
# 55: 2020 Christmas 수능 선물 https://t.co/XFla7GdWm0 2020 크리스마스 수능 선물 세일 정보 종합 상품 구매   fZm4 0.0
# 56: RT @mafavarchive: 💖 수능 이벤트 안내 💖
#
# 참여기간: 12월 7일 - 12월 12일
#
# 총 10분 추첨, 당첨 되신 분들에게 스티커팩을 보내드립니다! 모두 정말 수고 많으셨어요 💖
#
# https://t.co/72T2PoxOAT http… 0.4000000059604645
# 57: RT @NCTsmtown: 수능대박
#
# 으로 사행시 해보겠습니다
# 수:수능 대박나세요
# 능:윽..(할게없움ㅜ)
# 대:시즈니
# 박:화이팅💚🖤🤍😅
# #노력한거보다 #더잘나왔으면 #좋겠다
# #노더좋 #ㅋㅋㅋ #JS25 ###
# #JISUNG #NCT 0.20000000298023224
# 58: RT @MasterWhite18: Fact) 2014(2013.11 시행)~2017 국사 문제.
#
# 의외로 남북관계 문제는 유구한 날로먹기 문제였음.
#
# 무엇보다 2021 수능 저 보기의 케이스는 노태우 정권이었다는거고 그걸 가지고 정권 홍보라 그러는건… -0.10000000149011612
# 59: RT @ch9ettt: 솔직히 말해서 저희 회사가 저의 목표였겠습니까 여러분??? 저 MNH 몰랐어요 &lt; ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 수능 4일남았다고 너무 목표대학 어쩌구 매달릴 필요 없다면서 청하가 한 말 ㅋㅋㅋㅋㅋㅋ 0.0
# 60: 오늘 기말고사라서...
# 대충 유야도 고3인데 고3 2학기 기말을 어떻게 볼까?
#
# 쿨섹시한 선배니까 역시 고3 기말도 잘 보지 않을까? 하면서도 역시 수능 끝난 고3인데... 선배라고 해도 애들끼리 잘풀었냐가 아니라 잘찍었냐고 인사하지 않으려나아... -0.10000000149011612
# 61: RT @E_i_s_e: 데드맨 스위치 영원&amp;호현 수능썰 (고등학교 AU의 연장선으로 보아주세요😘) https://t.co/jFd0ih2Tub 0.0
# 62: RT @ES_Kwon: 내가 수능 보던 시절에도 점수 챙겨가라고 깔아주는 난이도 낮은 문제 있었던 걸로 기억하는데, 이게 저 정도로 논란이 될 일인가... 수능 가지고 정권홍보 한다고 잘못 물었다가 안되니깐 방향 돌린 느낌인데. ;
#
# https:/… -0.10000000149011612
# 63: RT @bighwanjang1: AI의 수능성적 https://t.co/yKKnNshVW4 0.0
# 64: @mapleS2gyuri 네 7시간자고 깨있는시간도 게임에 시간낭비해서 수능말고 꽃동네대학 21학번이된 저처럼만 안되길바랍니다👍 -0.30000001192092896
# 65: RT @KINGKKANG_DINOS: 누구는
# 수험생혜택 빕스50%와 롯월63%를
# 참으며살아가는데
# 수능친날도배달음식먹고
# 내마지막외출은 수능인채로
# 집에서썩어가는데진짜
# 좀사리ㅡㅁ들이 xx
# 89: RT @norang_7_0613: #아미트친소
# 저랑 잘 맞을것 같은 분들께 찾아가요~ 흔적 다 잡습니다💜
# 작년 이맘때 수능 조져서 사라졌었는데 전 트친분들은 아는척 해주시면 감사하겠습니다!! https://t.co/SEqoqslRfG 0.30000001192092896
# 90: RT @MasterWhite18: Fact) 2014(2013.11 시행)~2017 국사 문제.
#
# 의외로 남북관계 문제는 유구한 날로먹기 문제였음.
#
# 무엇보다 2021 수능 저 보기의 케이스는 노태우 정권이었다는거고 그걸 가지고 정권 홍보라 그러는건… -0.10000000149011612
# 91: 연대 논술 갈말중 수능 끝나고 처음 준비한 거라 가망성이 없어 보이기도 하고 어렵기도 하고 0.10000000149011612
# 92: RT @KBSnews: “수능 물리Ⅱ 18번 문항 오류…정답없음 처리 예상” #KBS뉴스 #KBS https://t.co/oW2ad3NjMj 0.0
# 93: 너무 가가고싶다 마지막외출이 수능인데요 아직 수험생 혜택 같은거 하나도 못받아봄 -0.5
# 94: RT @KINGKKANG_DINOS: 누구는
# 수험생혜택 빕스50%와 롯월63%를
# 참으며살아가는데
# 수능친날도배달음식먹고
# 내마지막외출은 수능인채로
# 집에서썩어가는데진짜
# 좀사리ㅡㅁ들이 xx
# 이제내마지막소원은 돼지국밥뿐인데
# 왜집에있질않아 내년에안전하게같이가자고 -0.10000000149011612
# 95: RT @bomandbee: 이벤트2.
# 2020 수능을 보신 수험생분들 한정으로 해당글 RT+팔로워 추첨 이벤트를 진행합니다🥳 올 한해 정말 고생 많으셨고 앞으로도 반짝반짝 좋은 일만 가득하시길 바라는 마음을 담아 당첨되신 한 분께 해당 20cm 아기… 0.4000000059604645
# 96: 아 미친... 수능 고사장에 확진자 있었데 -0.20000000298023224
# 97: @kitty_jkkk 수능 끝남 고삼이 가장 소매넣기 당하기 좋은 시기인 걸 모르나봄... 받아본 적이 없으니... 0.0
# 98: RT @bighwanjang1: AI의 수능성적 https://t.co/yKKnNshVW4 0.0
# 99: RT @moonriver126: 진정한 케이 고딩은 저런 뽀뽀쪽 이제 안무거워? 이딴 거 할 시간 없다고
# 아오늘도칠교시냐?조퇴각아니냐체육복두개인사람세특언제까지내야되는지아는사람수능며칠남았냐오늘급식뭐냐자살하러갈래요 이런얘기만해야된다고 -0.4000000059604645
# 100: RT @mafavarchive: 💖 수능 이벤트 안내 💖
#
# 참여기간: 12월 7일 - 12월 12일
#
# 총 10분 추첨, 당첨 되신 분들에게 스티커팩을 보내드립니다! 모두 정말 수고 많으셨어요 💖
#
# https://t.co/72T2PoxOAT http… 0.4000000059604645

# %%
show_wordcloud(good_text, bad_text)

# %% [markdown]
# ### *Reference*
# * [Why using APIs?](https://velog.io/@won-developer/API-%EB%9E%80)
# * [Twitter Sentiment Analysis with Machine Learning](https://monkeylearn.com/blog/sentiment-analysis-of-twitter/)
# * [Tweepy Usage](https://kslee7746.tistory.com/entry/python-tweepy-%EC%82%AC%EC%9A%A9%ED%95%9C-%ED%8A%B8%EC%9C%84%ED%84%B0-%ED%81%AC%EB%A1%A4%EB%A7%81crawling)
