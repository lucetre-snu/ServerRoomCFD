# %%
# import os
# subs = os.listdir('./submissions/')
# subs = sorted(subs)
# for i, sub in enumerate(subs):
#     new_name = '{:02d}_'.format(i) + '_'.join(sub.split('_')[:2])
#     os.rename('./submissions/'+sub, './submissions/'+new_name)
# Out:
# 00_강병준_2019-13418
# 01_강산_2016-11388
# 02_강세훈_2015-13458
# 03_고명진_2017-17745
# 04_고민재_2020-16440
# 05_고현우_2020-10712
# 06_공준형_2020-18978
# 07_공호세_2020-12406
# 08_길도형_2020-13936
# 09_김경훈_2016-16217
# 10_김규리_2018-12761
# 11_김도영_2016-16340
# 12_김도훈_2020-12780
# 13_김무성_2020-11138
# 14_김무승_2016-10621
# 15_김민지_2016-15447
# 16_김민지_2020-16672
# 17_김병욱_2017-19472
# 18_김승규_2020-18638
# 19_김영섭_2016-16994
# 20_김원준_2020-15583
# 21_김인태_2015-18771
# 22_김재빈_2020-17547
# 23_김준영_2020-17550
# 24_김지환_2018-14117
# 25_김진형_2019-11618
# 26_다윗_2019-19793
# 27_류경민_2018-17433
# 28_류명현_2019-13930
# 29_류성원_2020-11176
# 30_마훈_2019-16357
# 31_문민지_2019-14221
# 32_박민성_2018-14474
# 33_박범준_2013-11398
# 34_박송희_2017-10148
# 35_박원진_2020-17122
# 36_박정재_2020-19595
# 37_박지후_2015-15646
# 38_박찬우_2017-10291
# 39_박채원_2018-16927
# 40_박하언_2020-14603
# 41_배범규_2020-19067
# 42_백소은_2018-12781
# 43_백지원_2020-19212
# 44_서권찬_2020-14615
# 45_서준형_2019-18822
# 46_선가은_2020-18590
# 47_신다연_2020-19932
# 48_신정우_2016-11057
# 49_안건_2015-12429
# ...

# %%
import os
subs = os.listdir('./submissions/')
subs = sorted(subs)

# %%
for sub in subs:
    print(sub, end=':')
    src = [file for file in os.listdir('./submissions/'+sub) if file.endswith('.py')]
    print(src)
# Out:
# .ipynb_checkpoints:[]
# 00_강병준_2019-13418:['game.py']
# 01_강산_2016-11388:['game1p.py', 'game.py']
# 02_강세훈_2015-13458:['game.py']
# 03_고명진_2017-17745:['game.py']
# 04_고민재_2020-16440:['game.py']
# 05_고현우_2020-10712:['game.py']
# 06_공준형_2020-18978:['game.py']
# 07_공호세_2020-12406:['game.py']
# 08_길도형_2020-13936:['game.py']
# 09_김경훈_2016-16217:['game.py']
# 10_김규리_2018-12761:['game.py']
# 11_김도영_2016-16340:['game.py']
# 12_김도훈_2020-12780:['game.py']
# 13_김무성_2020-11138:['game.py']
# 14_김무승_2016-10621:['game.py']
# 15_김민지_2016-15447:['game.py']
# 16_김민지_2020-16672:['game.py']
# 17_김병욱_2017-19472:['game.py']
# 18_김승규_2020-18638:['game.py']
# 19_김영섭_2016-16994:['game.py']
# 20_김원준_2020-15583:['game.py']
# 21_김인태_2015-18771:['game.py']
# 22_김재빈_2020-17547:['game.py']
# 23_김준영_2020-17550:['game.py']
# 24_김지환_2018-14117:['game.py']
# 25_김진형_2019-11618:['colors.py', 'game.py']
# 26_다윗_2019-19793:['game.py']
# 27_류경민_2018-17433:['utils.py', 'snake.py', 'game.py']
# 28_류명현_2019-13930:['game.py']
# ...

# %%
from subprocess import call

for sub in subs[:1]:
    game_src = './submissions/' + sub + '/game.py'
    src = [file for file in os.listdir('./submissions/'+sub) if file.endswith('.py')]
    print(game_src)
    call(['python', game_src])
# Out:
# ./submissions/00_강병준_2019-13418/game.py
